# %% [markdown]
# **Sports injuries are unpredictable and are unavoidable if it befalls someone. Sports injuries occur during exercise or while participating in a sport. It is even common among sports players who are known to have a fit body and good physical fortitude, the reason being the excessive strain on the body due to overworking a particular muscle group or overstretching a particular muscle group. These are sports injuries that occur due to one’s negligence. While there is also another type of injury that occurs due to the initiative of others, that occurs due to foul play of the players. The latter kind of injuries are unpredictable, The first kind of injuries can be predicted which occurs due to repetitive action of the muscles and it can be avoided, which may help the player to last on the ground for more time and showcase his arsenal of plays. While it may seem data science has little to nothing in sports but on the contrary, it has a wide range of applications for it to be a domain in itself. Many different methods can be used to acquire data ie. either by asking players for feedback or video recordings of the players’ practices or by frequent medical check up data etc. The main motive is to identify a players fitness based on very important and general day to day attributes that affect one’s lifestyle, where these attributes are very different from the pure medical attributes.These data can be permuted and can be used for the identification of a sports injury that may happen in near future.**

# %%
import numpy as np
import sklearn
import graphviz
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
athletes=numpy.array([
    [8.0,3.2,105.0,1.4,21.1],
    [9.1,2.0,130,1.3,22.0],
    [7.0,4.1,82.0,1.1,23.1],
    [7.7,3.0,110,1.4,22.3],
    [8.0,2.2,128.0,1.5,23.3],
    [8.3,3.0,150,1.3,21.5],
    [8.0,3.3,182.0,1.6,24.0],
    [7.7,3.0,110,1.4,22.3],
    [8.5,3.2,150.0,1.3,23.0],
    [7.1,4.0,100,1.3,24.2],
    
])
df = pd.DataFrame(athletes, columns = ['Column_A','Column_B','Column_C','Column_D','Column_E'])
injuries=numpy.array([1,0,1,0,0,0,1,0,1,0])
X=athletes
y=injuries
df.columns
df
# Out:
#    Column_A  Column_B  Column_C  Column_D  Column_E
# 0       8.0       3.2     105.0       1.4      21.1
# 1       9.1       2.0     130.0       1.3      22.0
# 2       7.0       4.1      82.0       1.1      23.1
# 3       7.7       3.0     110.0       1.4      22.3
# 4       8.0       2.2     128.0       1.5      23.3
# 5       8.3       3.0     150.0       1.3      21.5
# 6       8.0       3.3     182.0       1.6      24.0
# 7       7.7       3.0     110.0       1.4      22.3
# 8       8.5       3.2     150.0       1.3      23.0
# 9       7.1       4.0     100.0       1.3      24.2

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)
trees=DecisionTreeClassifier(max_depth=4,random_state=0).fit(X,y)
print('Training set score: {:.3f}'.format(trees.score(X,y)))
X_new=numpy.array([10,4,70,1.0,22])
X_new=X_new.reshape(1,-1)
prediction=trees.predict(X_new)
print(prediction)
# Out:
# Training set score: 1.000
# [1]

# %%
def plot_f_importance(model):
    n_features=5
    plt.barh(range(n_features),model.feature_importances_,align='center')
    plt.yticks(numpy.arange(n_features),['a','b','c','d','e'])
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")
    plt.show()
plot_f_importance(trees)

# %%
from sklearn import tree
fig = plt.figure(figsize=(7,7))
_ = tree.plot_tree(trees, 
                   feature_names=['a','b','c','d','e'],  
                   class_names=['0','1'],
                   filled=True)

# %%
plt.figure(figsize=(100000,200000))
plt.style.use('ggplot')
n = 5
athlete1=(8.0,3.2,105.0,1.4,21.1)
athlete2=(9.1,2.0,130,1.3,22.0)
fig, ax = plt.subplots()
index = np.arange(n)
bar_width = 0.35
opacity = 1.0
ax.bar(index,athlete1 , bar_width, alpha=opacity, color='r',
                label='INJURED PLAYER')
ax.bar(index+bar_width,athlete2 , bar_width, alpha=opacity, color='b',
                label='NOT INJURED PLAYER')
ax.set_xlabel('FACTORS')
ax.set_ylabel('SCALE')
ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('sleep(hrs)','stress','TSS/d','ATL/CTL','BMI'))
ax.legend()
plt.show()
